# %%
import BioSimSpace as BSS
# Out:
# INFO:rdkit:Enabling RDKit 2025.03.6 jupyter extensions
# WARNING:pint.util:Redefining '[electric_potential]' (<class 'pint.delegates.txt_defparser.plain.DerivedDimensionDefinition'>)
# INFO:numexpr.utils:Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# INFO:numexpr.utils:NumExpr defaulting to 16 threads.

# %% [markdown]
# We can use `BioSimSpace.FreeEnergy.Relative.analyse` function to analyse our short free energy calculation:

# %%
pmf, overlap = BSS.FreeEnergy.Relative.analyse("../02_simulation/mdm2_e23g_open_conf_am7209_short_run/")
# Out:
# INFO:2026-06-26 18:35:33,815:jax._src.xla_bridge:924: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:2026-06-26 18:35:33,819:jax._src.xla_bridge:924: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory

# %% [markdown]
# Once the MBAR analysis is complete, we can extract our dG value:

# %%
BSS.FreeEnergy.Relative.difference(pmf)[0].value()
# Out:
# -7.3648339667250795

# %% [markdown]
# We can also use `BioSimSpace.Notebook.plotOverlapMatrix()` function to visualize the overlap matrix

# %%
BSS.Notebook.plotOverlapMatrix(overlap)
